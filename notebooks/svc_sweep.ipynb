# %%
import wandb

# %%
sweep_config = {
  'name': 'bayes_recall_fixed-split',
  'method': 'bayes',
  'program': 'train.py',
  'metric': {'name': 'pr',
             'goal': 'maximize'},
  'parameters': {
        'C': {
            'min': 0.0,
            'max': 1e4,
            'distribution': 'normal',
            'mu': 5e3,
            'sigma': 1e3
        },
       'gamma': {
           'min': 1.0,
           'max': 100.0,
           'distribution': 'uniform'
       }
    }
}

# %%
sweep_id = wandb.sweep(sweep_config, project="sysfake")
# Out:
# Create sweep with ID: 16fytl38
# Sweep URL: https://app.wandb.ai/hsdicicco/sysfake/sweeps/16fytl38

# %%
wandb.agent(sweep_id)
# Out:
# wandb: Agent Starting Run: msqd795e with config:
# 	C: 5738.2325441509665
# 	gamma: 81.69280770206738
# wandb: Agent Starting Run: os2fkxjd with config:
# 	C: 3226.354294854147
# 	gamma: 74.54341122526601
# wandb: Agent Starting Run: o2wh5ruk with config:
# 	C: 6345.803709964304
# 	gamma: 64.83816149666217
# wandb: Agent Starting Run: 5ym9esg4 with config:
# 	C: 5178.661807314892
# 	gamma: 48.99544640408211
# wandb: Agent Starting Run: 64q5m6gy with config:
# 	C: 7577.8716891797685
# 	gamma: 12.257653072050847
# wandb: Agent Starting Run: c66jjx6h with config:
# 	C: 5818.117099535571
# 	gamma: 82.18590324340076
# wandb: Agent Starting Run: b7k66zsw with config:
# 	C: 4979.623300915819
# 	gamma: 28.929372004119127
# wandb: Agent Starting Run: neqtk9a5 with config:
# 	C: 4712.272823970402
# 	gamma: 35.15819936720327
# wandb: Agent Starting Run: 0anq3gjq with config:
# 	C: 6194.6967685369955
# 	gamma: 99.04651164510554
# wandb: Agent Starting Run: y6ezmecg with config:
# 	C: 4195.713521218659
# 	gamma: 77.176949945858
# wandb: Agent Starting Run: xhp5y4x9 with config:
# 	C: 3335.626416959607
# 	gamma: 85.4191095515899
# wandb: Agent Starting Run: ibzwak2c with config:
# 	C: 5402.6514439294215
# 	gamma: 54.533330789249355
# wandb: Agent Starting Run: vvk3kzfu with config:
# 	C: 5761.819626395791
# 	gamma: 96.16220439143063
# wandb: Agent Starting Run: d4bnskhb with config:
# 	C: 6069.618267290185
# 	gamma: 71.14854277724595
# wandb: Agent Starting Run: gse4h26l with config:
# 	C: 4297.647381746677
# 	gamma: 45.98603747460835
# wandb: Agent Starting Run: fkeodtxg with config:
# 	C: 5298.415615562429
# 	gamma: 16.586852638083514
# wandb: Agent Starting Run: mmyomcc5 with config:
# 	C: 6570.140365621808
# 	gamma: 15.838175780491492
# wandb: Agent Starting Run: gl38p05y with config:
# 	C: 4535.283128962548
# 	gamma: 33.057459265506544
# wandb: Agent Starting Run: mqkig0qv with config:
# 	C: 4516.679066465032
# 	gamma: 97.6729446040034
# wandb: Agent Starting Run: 12w6zeaa with config:
# 	C: 5298.183920224377
# 	gamma: 54.49426630754089
# wandb: Agent Starting Run: kqvu7sw2 with config:
# 	C: 4732.05247706881
# 	gamma: 82.58150057800653
# wandb: Agent Starting Run: d9lpdtvg with config:
# 	C: 5863.428381846751
# 	gamma: 67.13143517503586
# wandb: Agent Starting Run: 1ck4jtyc with config:
# 	C: 3794.69252186256
# 	gamma: 33.569804807808175
# wandb: Agent Starting Run: k0unf9jw with config:
# 	C: 4685.962650390432
# 	gamma: 9.866542232086731
# wandb: Agent Starting Run: tcjmnhgg with config:
# 	C: 4749.486755975978
# 	gamma: 7.9261680212596834
# wandb: Agent Starting Run: 1pzo803h with config:
# 	C: 2991.6641947624066
# 	gamma: 99.5711508787783
# wandb: Agent Starting Run: nc4q51vl with config:
# 	C: 7757.29322244118
# 	gamma: 3.482139994594579
# wandb: Agent Starting Run: 03gty30f with config:
# 	C: 4301.320078817189
# 	gamma: 64.46729592516414
# wandb: Agent Starting Run: lluhhm7d with config:
# 	C: 5785.765302736633
# 	gamma: 96.78943829564345
# wandb: Agent Starting Run: gezv2gzn with config:
# 	C: 5953.49388181206
# 	gamma: 17.12298292639445
# wandb: Agent Starting Run: itf6l0dz with config:
# 	C: 5268.804066374449
# 	gamma: 40.950994505315585
# wandb: Agent Starting Run: ho8yd4em with config:
# 	C: 5465.976996713383
# 	gamma: 19.256216105017124
# wandb: Agent Starting Run: pb1hyi96 with config:
# 	C: 6511.5739814475855
# 	gamma: 17.866138945323193
# wandb: Agent Starting Run: urh95717 with config:
# 	C: 5109.584513711553
# 	gamma: 39.903920876463324
# wandb: Agent Starting Run: 1ws1wcsb with config:
# 	C: 5647.888037927862
# 	gamma: 70.11278862178915
# wandb: Agent Starting Run: 0of8irgq with config:
# 	C: 3830.3524491047583
# 	gamma: 86.4663123796318
# wandb: Agent Starting Run: es0p1o5c with config:
# 	C: 4955.061515930568
# 	gamma: 68.16547729255065
# wandb: Agent Starting Run: i33nozfw with config:
# 	C: 4539.503148830039
# 	gamma: 17.75773067287937
# wandb: Agent Starting Run: rytjcvue with config:
# 	C: 6418.0716709161
# 	gamma: 20.89271827878726
# wandb: Agent Starting Run: 8jqvk7tt with config:
# 	C: 3840.472160374442
# 	gamma: 62.557270456335814
# wandb: Agent Starting Run: yepcdhs8 with config:
# 	C: 3924.2546028945903
# 	gamma: 85.0034360623996
# wandb: Agent Starting Run: jvo71jrz with config:
# 	C: 6087.15937065158
# 	gamma: 26.265052510668625
# wandb: Agent Starting Run: 7tizzgl1 with config:
# 	C: 6140.226107748082
# 	gamma: 1.336574395922101
# wandb: Agent Starting Run: t8pgq7l6 with config:
# 	C: 5318.374992873817
# 	gamma: 79.23741602692614
# wandb: Agent Starting Run: y4oi2cwa with config:
# 	C: 5666.922667996492
# 	gamma: 56.75565138753196
# wandb: Agent Starting Run: qdm2n0u1 with config:
# 	C: 5524.600508139826
# 	gamma: 28.157085835910998
# wandb: Agent Starting Run: op137jom with config:
# 	C: 3986.6039133694044
# 	gamma: 42.882708128983985
# wandb: Agent Starting Run: ibksmp4m with config:
# 	C: 5503.530589137722
# 	gamma: 45.49136047605598
# wandb: Agent Starting Run: 8fce5m17 with config:
# 	C: 4731.839571538327
# 	gamma: 1.682982590268076
# wandb: Agent Starting Run: xju3doz0 with config:
# 	C: 5952.602736030028
# 	gamma: 48.49038642250791
# wandb: Agent Starting Run: c2y72um2 with config:
# 	C: 5356.3373011987105
# 	gamma: 65.03911396843988
# wandb: Agent Starting Run: 55lqz63s with config:
# 	C: 6853.60101301714
# 	gamma: 80.770569984037
# wandb: Agent Starting Run: bwuqn9jp with config:
# 	C: 4588.599453122117
# 	gamma: 47.183640039004366
# wandb: Agent Starting Run: fiir42i4 with config:
# 	C: 4698.867670087825
# 	gamma: 16.91332452003918
# wandb: Agent Starting Run: vv46e472 with config:
# 	C: 7003.69266736952
# 	gamma: 93.3048135433762
# wandb: Agent Starting Run: 6gevgycr with config:
# 	C: 4771.52821695791
# 	gamma: 34.07439159340483
# wandb: Agent Starting Run: giq3pp37 with config:
# 	C: 5413.402229054449
# 	gamma: 96.25207825926189
# wandb: Agent Starting Run: 52w4ia7f with config:
# 	C: 5560.624451052553
# 	gamma: 47.39778608938493
# wandb: Agent Starting Run: 1yphfdkd with config:
# 	C: 5961.724508512608
# 	gamma: 83.23406089929384
# wandb: Agent Starting Run: pn224bji with config:
# 	C: 4482.749244534848
# 	gamma: 40.811333915582814
# wandb: Agent Starting Run: gbxha55a with config:
# 	C: 4509.226330293547
# 	gamma: 36.26374828594158
# wandb: Agent Starting Run: dh75o5q7 with config:
# 	C: 4717.0588076935
# 	gamma: 36.84186455291224
# wandb: Agent Starting Run: 6xui1vzk with config:
# 	C: 4054.5093202683074
# 	gamma: 20.463982942099854
# wandb: Agent Starting Run: e3nweyqm with config:
# 	C: 4785.8254413248205
# 	gamma: 53.633932484898935
# wandb: Agent Starting Run: zj0qpzqi with config:
# 	C: 4215.418710070462
# 	gamma: 13.680198214795285
# wandb: Agent Starting Run: cz2tl1b6 with config:
# 	C: 4370.2070516712765
# 	gamma: 19.83547013737743
# wandb: Agent Starting Run: lzdcfiep with config:
# 	C: 4500.957858947436
# 	gamma: 19.67115996068626
# wandb: Agent Starting Run: aw08pxyq with config:
# 	C: 5015.529569025645
# 	gamma: 86.5265581135646
# wandb: Agent Starting Run: dfukpjxa with config:
# 	C: 5514.874507388253
# 	gamma: 21.76576104696886
# wandb: Agent Starting Run: 8xomf4un with config:
# 	C: 4588.151177756107
# 	gamma: 30.811069852673544
# wandb: Agent Starting Run: nk88g3nr with config:
# 	C: 5335.103913220762
# 	gamma: 32.49720080398715
# wandb: Agent Starting Run: 5kkjc63b with config:
# 	C: 5264.815989926505
# 	gamma: 12.915811053615984
# wandb: Agent Starting Run: hoo7jc3t with config:
# 	C: 5841.944915323289
# 	gamma: 12.501149520616737
# wandb: Agent Starting Run: 4x1la3z7 with config:
# 	C: 6210.142281907417
# 	gamma: 98.82451798795339
# wandb: Agent Starting Run: v2u5346m with config:
# 	C: 7406.609952964712
# 	gamma: 39.08542277051075
# wandb: Agent Starting Run: 53hd2mnt with config:
# 	C: 5347.217936895127
# 	gamma: 70.1173393652994
# wandb: Agent Starting Run: oql18yfu with config:
# 	C: 4900.404751130825
# 	gamma: 56.44710811023658
# wandb: Agent Starting Run: 0flnnl4u with config:
# 	C: 7391.72125096116
# 	gamma: 5.212142501978515
# wandb: Agent Starting Run: 1ksb5cby with config:
# 	C: 3747.8289007152516
# 	gamma: 40.85227093401122
# wandb: Agent Starting Run: pn7zd3lt with config:
# 	C: 5498.88644281869
# 	gamma: 29.335002912275943
# wandb: Agent Starting Run: j0p38ht3 with config:
# 	C: 5377.662112736325
# 	gamma: 38.31154063327346
# wandb: Agent Starting Run: qf3dy1xb with config:
# 	C: 4790.433583978288
# 	gamma: 77.03017354269296
# wandb: Agent Starting Run: gg5howhk with config:
# 	C: 4712.696802585031
# 	gamma: 14.8638517565997
# wandb: Agent Starting Run: mib2ol1p with config:
# 	C: 5628.530560051055
# 	gamma: 83.01735835395078
# wandb: Agent Starting Run: dtea21g4 with config:
# 	C: 4010.0212118603495
# 	gamma: 33.334524530351665
# wandb: Agent Starting Run: 3t3ymeu9 with config:
# 	C: 4779.492656584357
# 	gamma: 37.9797425273809
# wandb: Agent Starting Run: 2gb5ynay with config:
# 	C: 3331.6550639987363
# 	gamma: 48.50729561869473
# wandb: Agent Starting Run: gilnin5x with config:
# 	C: 6872.387609566943
# 	gamma: 13.644978987142071
# wandb: Agent Starting Run: 259ezuok with config:
# 	C: 3781.2987982120903
# 	gamma: 23.890198209526393
# wandb: Agent Starting Run: qqhbq8rc with config:
# 	C: 4871.697329963973
# 	gamma: 93.53048807314475
# wandb: Agent Starting Run: e54whjh0 with config:
# 	C: 3841.3440376139233
# 	gamma: 47.85437408629302
# wandb: Agent Starting Run: nfwqy5u0 with config:
# 	C: 3028.600984240639
# 	gamma: 35.13619666940777
# wandb: Agent Starting Run: niku330r with config:
# 	C: 5146.90505938632
# 	gamma: 98.69083369945253
# wandb: Agent Starting Run: knr90gw7 with config:
# 	C: 5584.895854664845
# 	gamma: 89.03495946120884
